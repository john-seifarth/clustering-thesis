# %%
# %cd ..
# Out:
# /Users/johnseifarth/Desktop/clustering-thesis

# %% [markdown]
# ## Data Preprocessing Function
#
# This function reads all CSV files from a specified input folder, concatenates them, and outputs the data grouped by task ID.

# %%
from src.preprocess import concatenate_csv

input_folder = 'data/raw/PSU_Q1_ISU'
concatenate_csv(input_folder)

# %% [markdown]
# ## Creating List of Responses for Slurm Job

# %%
from src.preprocess import save_response_text_only

save_response_text_only('data/processed/task_Q1_ISU.csv')
# Out:
# Response text saved to slurm/response_text.csv
